# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import scipy.stats as stats
from sklearn import preprocessing
# %matplotlib inline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SequentialFeatureSelector as sfs
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from scipy import stats
from scipy.stats import linregress
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_classification
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, concatenate
from tensorflow.keras.callbacks import EarlyStopping

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import dataset
train = pd.read_csv('/content/drive/MyDrive/trainProcessed.csv')
validate = pd.read_csv('/content/drive/MyDrive/validateProcessed.csv')
test = pd.read_csv('/content/drive/MyDrive/testProcessed.csv')

# %%
import ast
def convert_string_to_list(string):
    try:
        return ast.literal_eval(string)
    except ValueError:
        return []

# %%
train['DIFFERENTIAL_DIAGNOSIS'] = train['DIFFERENTIAL_DIAGNOSIS'].apply(convert_string_to_list)
test['DIFFERENTIAL_DIAGNOSIS'] = test['DIFFERENTIAL_DIAGNOSIS'].apply(convert_string_to_list)
validate['DIFFERENTIAL_DIAGNOSIS'] = validate['DIFFERENTIAL_DIAGNOSIS'].apply(convert_string_to_list)

# %%
unique_diseases = unique_diseases = sorted(list(set(train['PATHOLOGY'])))

def data_pre(df, unique_diseases):
    X = df.drop(['DIFFERENTIAL_DIAGNOSIS', 'PATHOLOGY', 'INITIAL_EVIDENCE'], axis=1)

    # Deal with DIFFERENTIAL_DIAGNOSIS
    y = []
    for diagnosis_list in df['DIFFERENTIAL_DIAGNOSIS']:
        diagnosis_encoding = np.zeros(len(unique_diseases))
        for diagnosis in diagnosis_list:
            if isinstance(diagnosis, list) and len(diagnosis) == 2:
                disease_name, probability = diagnosis
                if disease_name in unique_diseases:
                    index = unique_diseases.index(disease_name)
                    diagnosis_encoding[index] = probability
        y.append(diagnosis_encoding)
    y = pd.DataFrame(y, columns=unique_diseases)

    # PATHOLOGY
    pathology = df['PATHOLOGY']
    pathology_encoded = np.zeros((len(pathology), len(unique_diseases)))
    for i, disease in enumerate(pathology):
        if disease in unique_diseases:
            index = unique_diseases.index(disease)
            pathology_encoded[i, index] = 1
    pathology_encoded = pd.DataFrame(pathology_encoded, columns=unique_diseases)

    return X, y, pathology_encoded



X_train, y_train, pathology_encoded_train = data_pre(train, unique_diseases)
X_validate, y_validate, pathology_encoded_validate = data_pre(validate, unique_diseases)
X_test, y_test, pathology_encoded_test = data_pre(test, unique_diseases)

# %%
# Calculate GTPA@1
class GTPAat1(tf.keras.metrics.Metric):
    def __init__(self, name='gtpa_at_1', **kwargs):
        super(GTPAat1, self).__init__(name=name, **kwargs)
        self.correct_predictions = self.add_weight(name='cp', initializer='zeros')
        self.total_samples = self.add_weight(name='ts', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        top1_pred = tf.argmax(y_pred, axis=1)
        true_labels = tf.argmax(y_true, axis=1)
        correct_predictions = tf.cast(tf.equal(top1_pred, true_labels), tf.float32)
        self.correct_predictions.assign_add(tf.reduce_sum(correct_predictions))
        self.total_samples.assign_add(tf.cast(tf.size(true_labels), tf.float32))

    def result(self):
        return self.correct_predictions / self.total_samples

    def reset_states(self):
        self.correct_predictions.assign(0.0)
        self.total_samples.assign(0.0)

# %%
from tensorflow.keras.layers import LeakyReLU

model = Sequential()
model.add(Dense(1024, input_dim=X_train.shape[1]))
model.add(LeakyReLU(alpha=0.1))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(512))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.3))
model.add(Dense(y_train.shape[1], activation='sigmoid'))
optimizer = Adam(learning_rate=0.00005)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', GTPAat1()])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=200, batch_size=128, validation_data=(X_validate, y_validate), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 8013/8013 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.4780 - gtpa_at_1: 0.4780
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:2723: UserWarning: Metric GTPAat1 implements a `reset_states()` method; rename it to `reset_state()` (without the final "s"). The name `reset_states()` has been deprecated to improve API consistency.
#   m.reset_state()
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0828 - accuracy: 0.4780 - gtpa_at_1: 0.4780 - val_loss: 0.0619 - val_accuracy: 0.7110 - val_gtpa_at_1: 0.7110
# Epoch 2/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0611 - accuracy: 0.6163 - gtpa_at_1: 0.6163 - val_loss: 0.0592 - val_accuracy: 0.7713 - val_gtpa_at_1: 0.7713
# Epoch 3/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0593 - accuracy: 0.6764 - gtpa_at_1: 0.6764 - val_loss: 0.0581 - val_accuracy: 0.8073 - val_gtpa_at_1: 0.8073
# Epoch 4/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0586 - accuracy: 0.7083 - gtpa_at_1: 0.7083 - val_loss: 0.0574 - val_accuracy: 0.8392 - val_gtpa_at_1: 0.8392
# Epoch 5/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0581 - accuracy: 0.7282 - gtpa_at_1: 0.7282 - val_loss: 0.0571 - val_accuracy: 0.8401 - val_gtpa_at_1: 0.8401
# Epoch 6/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0578 - accuracy: 0.7413 - gtpa_at_1: 0.7413 - val_loss: 0.0568 - val_accuracy: 0.8654 - val_gtpa_at_1: 0.8654
# Epoch 7/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0576 - accuracy: 0.7507 - gtpa_at_1: 0.7507 - val_loss: 0.0566 - val_accuracy: 0.8770 - val_gtpa_at_1: 0.8770
# Epoch 8/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0575 - accuracy: 0.7580 - gtpa_at_1: 0.7580 - val_loss: 0.0565 - val_accuracy: 0.8793 - val_gtpa_at_1: 0.8793
# Epoch 9/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0573 - accuracy: 0.7632 - gtpa_at_1: 0.7632 - val_loss: 0.0564 - val_accuracy: 0.8843 - val_gtpa_at_1: 0.8843
# Epoch 10/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0572 - accuracy: 0.7680 - gtpa_at_1: 0.7680 - val_loss: 0.0563 - val_accuracy: 0.8908 - val_gtpa_at_1: 0.8908
# Epoch 11/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0571 - accuracy: 0.7707 - gtpa_at_1: 0.7707 - val_loss: 0.0563 - val_accuracy: 0.8962 - val_gtpa_at_1: 0.8962
# Epoch 12/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0571 - accuracy: 0.7742 - gtpa_at_1: 0.7742 - val_loss: 0.0562 - val_accuracy: 0.9002 - val_gtpa_at_1: 0.9002
# Epoch 13/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0570 - accuracy: 0.7768 - gtpa_at_1: 0.7768 - val_loss: 0.0562 - val_accuracy: 0.8976 - val_gtpa_at_1: 0.8976
# Epoch 14/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0570 - accuracy: 0.7785 - gtpa_at_1: 0.7785 - val_loss: 0.0561 - val_accuracy: 0.9076 - val_gtpa_at_1: 0.9076
# Epoch 15/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0569 - accuracy: 0.7808 - gtpa_at_1: 0.7808 - val_loss: 0.0561 - val_accuracy: 0.9030 - val_gtpa_at_1: 0.9030
# Epoch 16/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0569 - accuracy: 0.7817 - gtpa_at_1: 0.7817 - val_loss: 0.0561 - val_accuracy: 0.8975 - val_gtpa_at_1: 0.8975
# Epoch 17/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0568 - accuracy: 0.7837 - gtpa_at_1: 0.7837 - val_loss: 0.0561 - val_accuracy: 0.8931 - val_gtpa_at_1: 0.8931
# Epoch 18/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0568 - accuracy: 0.7843 - gtpa_at_1: 0.7843 - val_loss: 0.0560 - val_accuracy: 0.9165 - val_gtpa_at_1: 0.9165
# Epoch 19/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0568 - accuracy: 0.7858 - gtpa_at_1: 0.7858 - val_loss: 0.0560 - val_accuracy: 0.9000 - val_gtpa_at_1: 0.9000
# Epoch 20/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0568 - accuracy: 0.7867 - gtpa_at_1: 0.7867 - val_loss: 0.0560 - val_accuracy: 0.9110 - val_gtpa_at_1: 0.9110
# Epoch 21/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0567 - accuracy: 0.7874 - gtpa_at_1: 0.7874 - val_loss: 0.0560 - val_accuracy: 0.9093 - val_gtpa_at_1: 0.9093
# Epoch 22/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0567 - accuracy: 0.7881 - gtpa_at_1: 0.7881 - val_loss: 0.0560 - val_accuracy: 0.9068 - val_gtpa_at_1: 0.9068
# Epoch 23/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0567 - accuracy: 0.7890 - gtpa_at_1: 0.7890 - val_loss: 0.0559 - val_accuracy: 0.9138 - val_gtpa_at_1: 0.9138
# Epoch 24/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0567 - accuracy: 0.7896 - gtpa_at_1: 0.7896 - val_loss: 0.0559 - val_accuracy: 0.9175 - val_gtpa_at_1: 0.9175
# Epoch 25/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0567 - accuracy: 0.7900 - gtpa_at_1: 0.7900 - val_loss: 0.0559 - val_accuracy: 0.9003 - val_gtpa_at_1: 0.9003
# Epoch 26/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0567 - accuracy: 0.7902 - gtpa_at_1: 0.7902 - val_loss: 0.0559 - val_accuracy: 0.9061 - val_gtpa_at_1: 0.9061
# Epoch 27/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0566 - accuracy: 0.7907 - gtpa_at_1: 0.7907 - val_loss: 0.0559 - val_accuracy: 0.9137 - val_gtpa_at_1: 0.9137
# Epoch 28/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0566 - accuracy: 0.7914 - gtpa_at_1: 0.7914 - val_loss: 0.0559 - val_accuracy: 0.9136 - val_gtpa_at_1: 0.9136
# Epoch 29/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0566 - accuracy: 0.7918 - gtpa_at_1: 0.7918 - val_loss: 0.0559 - val_accuracy: 0.9106 - val_gtpa_at_1: 0.9106
# Epoch 30/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0566 - accuracy: 0.7918 - gtpa_at_1: 0.7918 - val_loss: 0.0559 - val_accuracy: 0.9127 - val_gtpa_at_1: 0.9127
# Epoch 31/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0566 - accuracy: 0.7925 - gtpa_at_1: 0.7925 - val_loss: 0.0559 - val_accuracy: 0.9161 - val_gtpa_at_1: 0.9161
# Epoch 32/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0566 - accuracy: 0.7922 - gtpa_at_1: 0.7922 - val_loss: 0.0559 - val_accuracy: 0.9041 - val_gtpa_at_1: 0.9041
# Epoch 33/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0566 - accuracy: 0.7927 - gtpa_at_1: 0.7927 - val_loss: 0.0558 - val_accuracy: 0.9046 - val_gtpa_at_1: 0.9046
# Epoch 34/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0566 - accuracy: 0.7921 - gtpa_at_1: 0.7921 - val_loss: 0.0558 - val_accuracy: 0.9119 - val_gtpa_at_1: 0.9119
# Epoch 35/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0566 - accuracy: 0.7931 - gtpa_at_1: 0.7931 - val_loss: 0.0558 - val_accuracy: 0.9178 - val_gtpa_at_1: 0.9178
# Epoch 36/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0565 - accuracy: 0.7940 - gtpa_at_1: 0.7940 - val_loss: 0.0558 - val_accuracy: 0.9112 - val_gtpa_at_1: 0.9112
# Epoch 37/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0565 - accuracy: 0.7939 - gtpa_at_1: 0.7939 - val_loss: 0.0558 - val_accuracy: 0.9180 - val_gtpa_at_1: 0.9180
# Epoch 38/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0565 - accuracy: 0.7939 - gtpa_at_1: 0.7939 - val_loss: 0.0559 - val_accuracy: 0.9079 - val_gtpa_at_1: 0.9079
# Epoch 39/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0565 - accuracy: 0.7942 - gtpa_at_1: 0.7942 - val_loss: 0.0558 - val_accuracy: 0.9111 - val_gtpa_at_1: 0.9111
# Epoch 40/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0565 - accuracy: 0.7944 - gtpa_at_1: 0.7944 - val_loss: 0.0558 - val_accuracy: 0.9131 - val_gtpa_at_1: 0.9131
# Epoch 41/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0565 - accuracy: 0.7940 - gtpa_at_1: 0.7940 - val_loss: 0.0558 - val_accuracy: 0.9171 - val_gtpa_at_1: 0.9171
# Epoch 42/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0565 - accuracy: 0.7954 - gtpa_at_1: 0.7954 - val_loss: 0.0558 - val_accuracy: 0.9161 - val_gtpa_at_1: 0.9161
# Epoch 43/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0565 - accuracy: 0.7950 - gtpa_at_1: 0.7950 - val_loss: 0.0558 - val_accuracy: 0.9131 - val_gtpa_at_1: 0.9131
# Epoch 44/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0565 - accuracy: 0.7953 - gtpa_at_1: 0.7953 - val_loss: 0.0558 - val_accuracy: 0.9095 - val_gtpa_at_1: 0.9095
# Epoch 45/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0565 - accuracy: 0.7953 - gtpa_at_1: 0.7953 - val_loss: 0.0558 - val_accuracy: 0.9160 - val_gtpa_at_1: 0.9160
# Epoch 46/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0565 - accuracy: 0.7951 - gtpa_at_1: 0.7951 - val_loss: 0.0558 - val_accuracy: 0.9164 - val_gtpa_at_1: 0.9164
# Epoch 47/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0565 - accuracy: 0.7956 - gtpa_at_1: 0.7956 - val_loss: 0.0558 - val_accuracy: 0.9187 - val_gtpa_at_1: 0.9187
# Epoch 48/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0565 - accuracy: 0.7954 - gtpa_at_1: 0.7954 - val_loss: 0.0558 - val_accuracy: 0.9193 - val_gtpa_at_1: 0.9193
# Epoch 49/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0565 - accuracy: 0.7959 - gtpa_at_1: 0.7959 - val_loss: 0.0558 - val_accuracy: 0.9156 - val_gtpa_at_1: 0.9156
# Epoch 50/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0565 - accuracy: 0.7954 - gtpa_at_1: 0.7954 - val_loss: 0.0558 - val_accuracy: 0.9069 - val_gtpa_at_1: 0.9069
# Epoch 51/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0565 - accuracy: 0.7958 - gtpa_at_1: 0.7958 - val_loss: 0.0558 - val_accuracy: 0.9183 - val_gtpa_at_1: 0.9183
# Epoch 52/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0565 - accuracy: 0.7960 - gtpa_at_1: 0.7960 - val_loss: 0.0558 - val_accuracy: 0.9238 - val_gtpa_at_1: 0.9238
# Epoch 53/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0565 - accuracy: 0.7963 - gtpa_at_1: 0.7963 - val_loss: 0.0558 - val_accuracy: 0.9147 - val_gtpa_at_1: 0.9147
# Epoch 54/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0564 - accuracy: 0.7963 - gtpa_at_1: 0.7963 - val_loss: 0.0558 - val_accuracy: 0.9224 - val_gtpa_at_1: 0.9224
# Epoch 55/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7957 - gtpa_at_1: 0.7957 - val_loss: 0.0558 - val_accuracy: 0.9157 - val_gtpa_at_1: 0.9157
# Epoch 56/200
# 8013/8013 [==============================] - 109s 14ms/step - loss: 0.0564 - accuracy: 0.7962 - gtpa_at_1: 0.7962 - val_loss: 0.0558 - val_accuracy: 0.9148 - val_gtpa_at_1: 0.9148
# Epoch 57/200
# 8013/8013 [==============================] - 109s 14ms/step - loss: 0.0564 - accuracy: 0.7968 - gtpa_at_1: 0.7968 - val_loss: 0.0558 - val_accuracy: 0.9205 - val_gtpa_at_1: 0.9205
# Epoch 58/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0564 - accuracy: 0.7965 - gtpa_at_1: 0.7965 - val_loss: 0.0558 - val_accuracy: 0.9159 - val_gtpa_at_1: 0.9159
# Epoch 59/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0564 - accuracy: 0.7962 - gtpa_at_1: 0.7962 - val_loss: 0.0558 - val_accuracy: 0.9218 - val_gtpa_at_1: 0.9218
# Epoch 60/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7967 - gtpa_at_1: 0.7967 - val_loss: 0.0558 - val_accuracy: 0.9207 - val_gtpa_at_1: 0.9207
# Epoch 61/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0564 - accuracy: 0.7961 - gtpa_at_1: 0.7961 - val_loss: 0.0557 - val_accuracy: 0.9126 - val_gtpa_at_1: 0.9126
# Epoch 62/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0564 - accuracy: 0.7966 - gtpa_at_1: 0.7966 - val_loss: 0.0558 - val_accuracy: 0.9122 - val_gtpa_at_1: 0.9122
# Epoch 63/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0564 - accuracy: 0.7963 - gtpa_at_1: 0.7963 - val_loss: 0.0557 - val_accuracy: 0.9188 - val_gtpa_at_1: 0.9188
# Epoch 64/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7967 - gtpa_at_1: 0.7967 - val_loss: 0.0557 - val_accuracy: 0.9165 - val_gtpa_at_1: 0.9165
# Epoch 65/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7968 - gtpa_at_1: 0.7968 - val_loss: 0.0557 - val_accuracy: 0.9208 - val_gtpa_at_1: 0.9208
# Epoch 66/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7972 - gtpa_at_1: 0.7972 - val_loss: 0.0557 - val_accuracy: 0.9192 - val_gtpa_at_1: 0.9192
# Epoch 67/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0564 - accuracy: 0.7965 - gtpa_at_1: 0.7965 - val_loss: 0.0557 - val_accuracy: 0.9115 - val_gtpa_at_1: 0.9115
# Epoch 68/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0564 - accuracy: 0.7978 - gtpa_at_1: 0.7978 - val_loss: 0.0557 - val_accuracy: 0.9168 - val_gtpa_at_1: 0.9168
# Epoch 69/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0564 - accuracy: 0.7973 - gtpa_at_1: 0.7973 - val_loss: 0.0557 - val_accuracy: 0.9196 - val_gtpa_at_1: 0.9196
# Epoch 70/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0564 - accuracy: 0.7972 - gtpa_at_1: 0.7972 - val_loss: 0.0557 - val_accuracy: 0.9272 - val_gtpa_at_1: 0.9272
# Epoch 71/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0564 - accuracy: 0.7974 - gtpa_at_1: 0.7974 - val_loss: 0.0557 - val_accuracy: 0.9203 - val_gtpa_at_1: 0.9203
# Epoch 72/200
# 8013/8013 [==============================] - 109s 14ms/step - loss: 0.0564 - accuracy: 0.7971 - gtpa_at_1: 0.7971 - val_loss: 0.0557 - val_accuracy: 0.9265 - val_gtpa_at_1: 0.9265
# Epoch 73/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0564 - accuracy: 0.7977 - gtpa_at_1: 0.7977 - val_loss: 0.0557 - val_accuracy: 0.9120 - val_gtpa_at_1: 0.9120
# Epoch 74/200
# 8013/8013 [==============================] - 109s 14ms/step - loss: 0.0564 - accuracy: 0.7974 - gtpa_at_1: 0.7974 - val_loss: 0.0557 - val_accuracy: 0.9167 - val_gtpa_at_1: 0.9167
# Epoch 75/200
# 8013/8013 [==============================] - 109s 14ms/step - loss: 0.0564 - accuracy: 0.7978 - gtpa_at_1: 0.7978 - val_loss: 0.0557 - val_accuracy: 0.9190 - val_gtpa_at_1: 0.9190
# Epoch 76/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0564 - accuracy: 0.7973 - gtpa_at_1: 0.7973 - val_loss: 0.0557 - val_accuracy: 0.9065 - val_gtpa_at_1: 0.9065
# Epoch 77/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0564 - accuracy: 0.7969 - gtpa_at_1: 0.7969 - val_loss: 0.0557 - val_accuracy: 0.9185 - val_gtpa_at_1: 0.9185
# Epoch 78/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7972 - gtpa_at_1: 0.7972 - val_loss: 0.0557 - val_accuracy: 0.9181 - val_gtpa_at_1: 0.9181
# Epoch 79/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7977 - gtpa_at_1: 0.7977 - val_loss: 0.0557 - val_accuracy: 0.9199 - val_gtpa_at_1: 0.9199
# Epoch 80/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7971 - gtpa_at_1: 0.7971 - val_loss: 0.0557 - val_accuracy: 0.9140 - val_gtpa_at_1: 0.9140
# Epoch 81/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0564 - accuracy: 0.7975 - gtpa_at_1: 0.7975 - val_loss: 0.0557 - val_accuracy: 0.9217 - val_gtpa_at_1: 0.9217
# Epoch 82/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0564 - accuracy: 0.7975 - gtpa_at_1: 0.7975 - val_loss: 0.0557 - val_accuracy: 0.9165 - val_gtpa_at_1: 0.9165
# Epoch 83/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0564 - accuracy: 0.7977 - gtpa_at_1: 0.7977 - val_loss: 0.0557 - val_accuracy: 0.9118 - val_gtpa_at_1: 0.9118
# Epoch 84/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0564 - accuracy: 0.7979 - gtpa_at_1: 0.7979 - val_loss: 0.0557 - val_accuracy: 0.9155 - val_gtpa_at_1: 0.9155
# Epoch 85/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0564 - accuracy: 0.7977 - gtpa_at_1: 0.7977 - val_loss: 0.0557 - val_accuracy: 0.9257 - val_gtpa_at_1: 0.9257
# Epoch 86/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0564 - accuracy: 0.7984 - gtpa_at_1: 0.7984 - val_loss: 0.0557 - val_accuracy: 0.9160 - val_gtpa_at_1: 0.9160
# Epoch 87/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0564 - accuracy: 0.7977 - gtpa_at_1: 0.7977 - val_loss: 0.0557 - val_accuracy: 0.9183 - val_gtpa_at_1: 0.9183
# Epoch 88/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0564 - accuracy: 0.7973 - gtpa_at_1: 0.7973 - val_loss: 0.0557 - val_accuracy: 0.9182 - val_gtpa_at_1: 0.9182
# Epoch 89/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0564 - accuracy: 0.7981 - gtpa_at_1: 0.7981 - val_loss: 0.0557 - val_accuracy: 0.9202 - val_gtpa_at_1: 0.9202
# Epoch 90/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7975 - gtpa_at_1: 0.7975 - val_loss: 0.0557 - val_accuracy: 0.9166 - val_gtpa_at_1: 0.9166
# Epoch 91/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0564 - accuracy: 0.7978 - gtpa_at_1: 0.7978 - val_loss: 0.0557 - val_accuracy: 0.9257 - val_gtpa_at_1: 0.9257
# Epoch 92/200
# 8013/8013 [==============================] - 109s 14ms/step - loss: 0.0564 - accuracy: 0.7983 - gtpa_at_1: 0.7983 - val_loss: 0.0557 - val_accuracy: 0.9196 - val_gtpa_at_1: 0.9196
# Epoch 93/200
# 8013/8013 [==============================] - 110s 14ms/step - loss: 0.0564 - accuracy: 0.7976 - gtpa_at_1: 0.7976 - val_loss: 0.0557 - val_accuracy: 0.9188 - val_gtpa_at_1: 0.9188
# Epoch 94/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0564 - accuracy: 0.7977 - gtpa_at_1: 0.7977 - val_loss: 0.0557 - val_accuracy: 0.9234 - val_gtpa_at_1: 0.9234
# Epoch 95/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0564 - accuracy: 0.7983 - gtpa_at_1: 0.7983 - val_loss: 0.0557 - val_accuracy: 0.9126 - val_gtpa_at_1: 0.9126
# Epoch 96/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0563 - accuracy: 0.7985 - gtpa_at_1: 0.7985 - val_loss: 0.0557 - val_accuracy: 0.9194 - val_gtpa_at_1: 0.9194
# Epoch 97/200
# 8013/8013 [==============================] - 108s 13ms/step - loss: 0.0563 - accuracy: 0.7979 - gtpa_at_1: 0.7979 - val_loss: 0.0557 - val_accuracy: 0.9193 - val_gtpa_at_1: 0.9193
# Epoch 98/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7984 - gtpa_at_1: 0.7984 - val_loss: 0.0557 - val_accuracy: 0.9243 - val_gtpa_at_1: 0.9243
# Epoch 99/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7977 - gtpa_at_1: 0.7977 - val_loss: 0.0557 - val_accuracy: 0.9257 - val_gtpa_at_1: 0.9257
# Epoch 100/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7981 - gtpa_at_1: 0.7981 - val_loss: 0.0557 - val_accuracy: 0.9130 - val_gtpa_at_1: 0.9130
# Epoch 101/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7979 - gtpa_at_1: 0.7979 - val_loss: 0.0557 - val_accuracy: 0.9254 - val_gtpa_at_1: 0.9254
# Epoch 102/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7979 - gtpa_at_1: 0.7979 - val_loss: 0.0557 - val_accuracy: 0.9121 - val_gtpa_at_1: 0.9121
# Epoch 103/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7981 - gtpa_at_1: 0.7981 - val_loss: 0.0557 - val_accuracy: 0.9278 - val_gtpa_at_1: 0.9278
# Epoch 104/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7982 - gtpa_at_1: 0.7982 - val_loss: 0.0557 - val_accuracy: 0.9194 - val_gtpa_at_1: 0.9194
# Epoch 105/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7980 - gtpa_at_1: 0.7980 - val_loss: 0.0557 - val_accuracy: 0.9247 - val_gtpa_at_1: 0.9247
# Epoch 106/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7983 - gtpa_at_1: 0.7983 - val_loss: 0.0557 - val_accuracy: 0.9251 - val_gtpa_at_1: 0.9251
# Epoch 107/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7985 - gtpa_at_1: 0.7985 - val_loss: 0.0557 - val_accuracy: 0.9230 - val_gtpa_at_1: 0.9230
# Epoch 108/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7985 - gtpa_at_1: 0.7985 - val_loss: 0.0557 - val_accuracy: 0.9200 - val_gtpa_at_1: 0.9200
# Epoch 109/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9111 - val_gtpa_at_1: 0.9111
# Epoch 110/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0563 - accuracy: 0.7992 - gtpa_at_1: 0.7992 - val_loss: 0.0557 - val_accuracy: 0.9194 - val_gtpa_at_1: 0.9194
# Epoch 111/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0563 - accuracy: 0.7984 - gtpa_at_1: 0.7984 - val_loss: 0.0557 - val_accuracy: 0.9190 - val_gtpa_at_1: 0.9190
# Epoch 112/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7983 - gtpa_at_1: 0.7983 - val_loss: 0.0557 - val_accuracy: 0.9164 - val_gtpa_at_1: 0.9164
# Epoch 113/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7982 - gtpa_at_1: 0.7982 - val_loss: 0.0557 - val_accuracy: 0.9201 - val_gtpa_at_1: 0.9201
# Epoch 114/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7981 - gtpa_at_1: 0.7981 - val_loss: 0.0557 - val_accuracy: 0.9179 - val_gtpa_at_1: 0.9179
# Epoch 115/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9197 - val_gtpa_at_1: 0.9197
# Epoch 116/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0557 - val_accuracy: 0.9170 - val_gtpa_at_1: 0.9170
# Epoch 117/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7984 - gtpa_at_1: 0.7984 - val_loss: 0.0557 - val_accuracy: 0.9125 - val_gtpa_at_1: 0.9125
# Epoch 118/200
# 8013/8013 [==============================] - 104s 13ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9165 - val_gtpa_at_1: 0.9165
# Epoch 119/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7983 - gtpa_at_1: 0.7983 - val_loss: 0.0557 - val_accuracy: 0.9138 - val_gtpa_at_1: 0.9138
# Epoch 120/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0557 - val_accuracy: 0.9140 - val_gtpa_at_1: 0.9140
# Epoch 121/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7983 - gtpa_at_1: 0.7983 - val_loss: 0.0557 - val_accuracy: 0.9175 - val_gtpa_at_1: 0.9175
# Epoch 122/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0557 - val_accuracy: 0.9226 - val_gtpa_at_1: 0.9226
# Epoch 123/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9208 - val_gtpa_at_1: 0.9208
# Epoch 124/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0563 - accuracy: 0.7980 - gtpa_at_1: 0.7980 - val_loss: 0.0557 - val_accuracy: 0.9209 - val_gtpa_at_1: 0.9209
# Epoch 125/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9081 - val_gtpa_at_1: 0.9081
# Epoch 126/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0557 - val_accuracy: 0.9045 - val_gtpa_at_1: 0.9045
# Epoch 127/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0563 - accuracy: 0.7987 - gtpa_at_1: 0.7987 - val_loss: 0.0557 - val_accuracy: 0.9189 - val_gtpa_at_1: 0.9189
# Epoch 128/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9241 - val_gtpa_at_1: 0.9241
# Epoch 129/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7985 - gtpa_at_1: 0.7985 - val_loss: 0.0557 - val_accuracy: 0.9180 - val_gtpa_at_1: 0.9180
# Epoch 130/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7981 - gtpa_at_1: 0.7981 - val_loss: 0.0557 - val_accuracy: 0.9212 - val_gtpa_at_1: 0.9212
# Epoch 131/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7984 - gtpa_at_1: 0.7984 - val_loss: 0.0557 - val_accuracy: 0.9149 - val_gtpa_at_1: 0.9149
# Epoch 132/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7980 - gtpa_at_1: 0.7980 - val_loss: 0.0557 - val_accuracy: 0.9217 - val_gtpa_at_1: 0.9217
# Epoch 133/200
# 8013/8013 [==============================] - 105s 13ms/step - loss: 0.0563 - accuracy: 0.7985 - gtpa_at_1: 0.7985 - val_loss: 0.0557 - val_accuracy: 0.9195 - val_gtpa_at_1: 0.9195
# Epoch 134/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9289 - val_gtpa_at_1: 0.9289
# Epoch 135/200
# 8013/8013 [==============================] - 106s 13ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9073 - val_gtpa_at_1: 0.9073
# Epoch 136/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0563 - accuracy: 0.7984 - gtpa_at_1: 0.7984 - val_loss: 0.0557 - val_accuracy: 0.9131 - val_gtpa_at_1: 0.9131
# Epoch 137/200
# 8013/8013 [==============================] - 107s 13ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9214 - val_gtpa_at_1: 0.9214
# Epoch 138/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9152 - val_gtpa_at_1: 0.9152
# Epoch 139/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9170 - val_gtpa_at_1: 0.9170
# Epoch 140/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7993 - gtpa_at_1: 0.7993 - val_loss: 0.0557 - val_accuracy: 0.9197 - val_gtpa_at_1: 0.9197
# Epoch 141/200
# 8013/8013 [==============================] - 121s 15ms/step - loss: 0.0563 - accuracy: 0.7991 - gtpa_at_1: 0.7991 - val_loss: 0.0557 - val_accuracy: 0.9246 - val_gtpa_at_1: 0.9246
# Epoch 142/200
# 8013/8013 [==============================] - 118s 15ms/step - loss: 0.0563 - accuracy: 0.7992 - gtpa_at_1: 0.7992 - val_loss: 0.0557 - val_accuracy: 0.9194 - val_gtpa_at_1: 0.9194
# Epoch 143/200
# 8013/8013 [==============================] - 115s 14ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9283 - val_gtpa_at_1: 0.9283
# Epoch 144/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9162 - val_gtpa_at_1: 0.9162
# Epoch 145/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7991 - gtpa_at_1: 0.7991 - val_loss: 0.0557 - val_accuracy: 0.9231 - val_gtpa_at_1: 0.9231
# Epoch 146/200
# 8013/8013 [==============================] - 116s 14ms/step - loss: 0.0563 - accuracy: 0.7994 - gtpa_at_1: 0.7994 - val_loss: 0.0557 - val_accuracy: 0.9253 - val_gtpa_at_1: 0.9253
# Epoch 147/200
# 8013/8013 [==============================] - 115s 14ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9161 - val_gtpa_at_1: 0.9161
# Epoch 148/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9151 - val_gtpa_at_1: 0.9151
# Epoch 149/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7992 - gtpa_at_1: 0.7992 - val_loss: 0.0557 - val_accuracy: 0.9231 - val_gtpa_at_1: 0.9231
# Epoch 150/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9231 - val_gtpa_at_1: 0.9231
# Epoch 151/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7993 - gtpa_at_1: 0.7993 - val_loss: 0.0557 - val_accuracy: 0.9046 - val_gtpa_at_1: 0.9046
# Epoch 152/200
# 8013/8013 [==============================] - 110s 14ms/step - loss: 0.0563 - accuracy: 0.7985 - gtpa_at_1: 0.7985 - val_loss: 0.0557 - val_accuracy: 0.9196 - val_gtpa_at_1: 0.9196
# Epoch 153/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9292 - val_gtpa_at_1: 0.9292
# Epoch 154/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9068 - val_gtpa_at_1: 0.9068
# Epoch 155/200
# 8013/8013 [==============================] - 111s 14ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9112 - val_gtpa_at_1: 0.9112
# Epoch 156/200
# 8013/8013 [==============================] - 116s 14ms/step - loss: 0.0563 - accuracy: 0.7984 - gtpa_at_1: 0.7984 - val_loss: 0.0557 - val_accuracy: 0.9176 - val_gtpa_at_1: 0.9176
# Epoch 157/200
# 8013/8013 [==============================] - 117s 15ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9162 - val_gtpa_at_1: 0.9162
# Epoch 158/200
# 8013/8013 [==============================] - 118s 15ms/step - loss: 0.0563 - accuracy: 0.7991 - gtpa_at_1: 0.7991 - val_loss: 0.0557 - val_accuracy: 0.9124 - val_gtpa_at_1: 0.9124
# Epoch 159/200
# 8013/8013 [==============================] - 116s 15ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9248 - val_gtpa_at_1: 0.9248
# Epoch 160/200
# 8013/8013 [==============================] - 116s 15ms/step - loss: 0.0563 - accuracy: 0.7987 - gtpa_at_1: 0.7987 - val_loss: 0.0557 - val_accuracy: 0.9249 - val_gtpa_at_1: 0.9249
# Epoch 161/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7987 - gtpa_at_1: 0.7987 - val_loss: 0.0557 - val_accuracy: 0.9107 - val_gtpa_at_1: 0.9107
# Epoch 162/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0557 - val_accuracy: 0.9211 - val_gtpa_at_1: 0.9211
# Epoch 163/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9264 - val_gtpa_at_1: 0.9264
# Epoch 164/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0557 - val_accuracy: 0.9241 - val_gtpa_at_1: 0.9241
# Epoch 165/200
# 8013/8013 [==============================] - 110s 14ms/step - loss: 0.0563 - accuracy: 0.7995 - gtpa_at_1: 0.7995 - val_loss: 0.0557 - val_accuracy: 0.9171 - val_gtpa_at_1: 0.9171
# Epoch 166/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9224 - val_gtpa_at_1: 0.9224
# Epoch 167/200
# 8013/8013 [==============================] - 111s 14ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9244 - val_gtpa_at_1: 0.9244
# Epoch 168/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9166 - val_gtpa_at_1: 0.9166
# Epoch 169/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9267 - val_gtpa_at_1: 0.9267
# Epoch 170/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7992 - gtpa_at_1: 0.7992 - val_loss: 0.0557 - val_accuracy: 0.9235 - val_gtpa_at_1: 0.9235
# Epoch 171/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9210 - val_gtpa_at_1: 0.9210
# Epoch 172/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7994 - gtpa_at_1: 0.7994 - val_loss: 0.0557 - val_accuracy: 0.9013 - val_gtpa_at_1: 0.9013
# Epoch 173/200
# 8013/8013 [==============================] - 115s 14ms/step - loss: 0.0563 - accuracy: 0.7997 - gtpa_at_1: 0.7997 - val_loss: 0.0557 - val_accuracy: 0.9217 - val_gtpa_at_1: 0.9217
# Epoch 174/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7991 - gtpa_at_1: 0.7991 - val_loss: 0.0557 - val_accuracy: 0.9207 - val_gtpa_at_1: 0.9207
# Epoch 175/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7992 - gtpa_at_1: 0.7992 - val_loss: 0.0556 - val_accuracy: 0.9140 - val_gtpa_at_1: 0.9140
# Epoch 176/200
# 8013/8013 [==============================] - 118s 15ms/step - loss: 0.0563 - accuracy: 0.7991 - gtpa_at_1: 0.7991 - val_loss: 0.0557 - val_accuracy: 0.9184 - val_gtpa_at_1: 0.9184
# Epoch 177/200
# 8013/8013 [==============================] - 118s 15ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9258 - val_gtpa_at_1: 0.9258
# Epoch 178/200
# 8013/8013 [==============================] - 115s 14ms/step - loss: 0.0563 - accuracy: 0.7995 - gtpa_at_1: 0.7995 - val_loss: 0.0557 - val_accuracy: 0.9223 - val_gtpa_at_1: 0.9223
# Epoch 179/200
# 8013/8013 [==============================] - 111s 14ms/step - loss: 0.0563 - accuracy: 0.7996 - gtpa_at_1: 0.7996 - val_loss: 0.0557 - val_accuracy: 0.9158 - val_gtpa_at_1: 0.9158
# Epoch 180/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9222 - val_gtpa_at_1: 0.9222
# Epoch 181/200
# 8013/8013 [==============================] - 111s 14ms/step - loss: 0.0563 - accuracy: 0.7991 - gtpa_at_1: 0.7991 - val_loss: 0.0557 - val_accuracy: 0.9237 - val_gtpa_at_1: 0.9237
# Epoch 182/200
# 8013/8013 [==============================] - 110s 14ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0557 - val_accuracy: 0.9182 - val_gtpa_at_1: 0.9182
# Epoch 183/200
# 8013/8013 [==============================] - 110s 14ms/step - loss: 0.0563 - accuracy: 0.7992 - gtpa_at_1: 0.7992 - val_loss: 0.0556 - val_accuracy: 0.9203 - val_gtpa_at_1: 0.9203
# Epoch 184/200
# 8013/8013 [==============================] - 110s 14ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0556 - val_accuracy: 0.9244 - val_gtpa_at_1: 0.9244
# Epoch 185/200
# 8013/8013 [==============================] - 109s 14ms/step - loss: 0.0563 - accuracy: 0.7991 - gtpa_at_1: 0.7991 - val_loss: 0.0557 - val_accuracy: 0.9299 - val_gtpa_at_1: 0.9299
# Epoch 186/200
# 8013/8013 [==============================] - 111s 14ms/step - loss: 0.0563 - accuracy: 0.7991 - gtpa_at_1: 0.7991 - val_loss: 0.0556 - val_accuracy: 0.9177 - val_gtpa_at_1: 0.9177
# Epoch 187/200
# 8013/8013 [==============================] - 111s 14ms/step - loss: 0.0563 - accuracy: 0.7992 - gtpa_at_1: 0.7992 - val_loss: 0.0557 - val_accuracy: 0.9168 - val_gtpa_at_1: 0.9168
# Epoch 188/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7993 - gtpa_at_1: 0.7993 - val_loss: 0.0556 - val_accuracy: 0.9229 - val_gtpa_at_1: 0.9229
# Epoch 189/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7986 - gtpa_at_1: 0.7986 - val_loss: 0.0557 - val_accuracy: 0.9161 - val_gtpa_at_1: 0.9161
# Epoch 190/200
# 8013/8013 [==============================] - 116s 14ms/step - loss: 0.0563 - accuracy: 0.7994 - gtpa_at_1: 0.7994 - val_loss: 0.0557 - val_accuracy: 0.9152 - val_gtpa_at_1: 0.9152
# Epoch 191/200
# 8013/8013 [==============================] - 116s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0556 - val_accuracy: 0.9200 - val_gtpa_at_1: 0.9200
# Epoch 192/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7995 - gtpa_at_1: 0.7995 - val_loss: 0.0557 - val_accuracy: 0.9222 - val_gtpa_at_1: 0.9222
# Epoch 193/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9197 - val_gtpa_at_1: 0.9197
# Epoch 194/200
# 8013/8013 [==============================] - 114s 14ms/step - loss: 0.0563 - accuracy: 0.7988 - gtpa_at_1: 0.7988 - val_loss: 0.0556 - val_accuracy: 0.9245 - val_gtpa_at_1: 0.9245
# Epoch 195/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0557 - val_accuracy: 0.9145 - val_gtpa_at_1: 0.9145
# Epoch 196/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7990 - gtpa_at_1: 0.7990 - val_loss: 0.0556 - val_accuracy: 0.9091 - val_gtpa_at_1: 0.9091
# Epoch 197/200
# 8013/8013 [==============================] - 113s 14ms/step - loss: 0.0563 - accuracy: 0.8002 - gtpa_at_1: 0.8002 - val_loss: 0.0557 - val_accuracy: 0.9260 - val_gtpa_at_1: 0.9260
# Epoch 198/200
# 8013/8013 [==============================] - 112s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0556 - val_accuracy: 0.9234 - val_gtpa_at_1: 0.9234
# Epoch 199/200
# 8013/8013 [==============================] - 111s 14ms/step - loss: 0.0563 - accuracy: 0.7989 - gtpa_at_1: 0.7989 - val_loss: 0.0557 - val_accuracy: 0.9179 - val_gtpa_at_1: 0.9179
# Epoch 200/200
# 8013/8013 [==============================] - 111s 14ms/step - loss: 0.0563 - accuracy: 0.7994 - gtpa_at_1: 0.7994 - val_loss: 0.0557 - val_accuracy: 0.9199 - val_gtpa_at_1: 0.9199

# %%
gtpa_at1_metric=GTPAat1()

# On Validation set
y_pred_validate = model.predict(X_validate, batch_size=128)
gtpa_at1_metric.update_state(pathology_encoded_validate, y_pred_validate)
gtpa_at1_validate = gtpa_at1_metric.result().numpy()
print("GTPA@1 on Validation Set:", gtpa_at1_validate)


gtpa_at1_metric.reset_states()

# On test Set
y_pred_test = model.predict(X_test, batch_size=128)
gtpa_at1_metric.update_state(pathology_encoded_test, y_pred_test)
gtpa_at1_test = gtpa_at1_metric.result().numpy()
print("GTPA@1 on Test Set:", gtpa_at1_test)
# Out:
# 1035/1035 [==============================] - 4s 4ms/step
# GTPA@1 on Validation Set: 0.7367646
# 1052/1052 [==============================] - 4s 4ms/step
# GTPA@1 on Test Set: 0.7373429

# %%
def calculate_DDR(y_true, y_pred, threshold=0.01):
  #turn prediction intro binary according to the threshold
    y_true_binary = (y_true > threshold).astype(int)
    y_pred_binary = (y_pred > threshold).astype(int)

    # calculate DDR
    DDR = np.mean([
        np.sum(y_true_binary[i] & y_pred_binary[i]) / np.sum(y_true_binary[i])
        if np.sum(y_true_binary[i]) > 0 else 0
        for i in range(y_true_binary.shape[0])
    ])
    return DDR


def calculate_DDP(y_true, y_pred, threshold=0.01):
  #turn prediction intro binary according to the threshold
    y_true_binary = (y_true > threshold).astype(int)
    y_pred_binary = (y_pred > threshold).astype(int)

   # calculate DDP
    DDP = np.mean([
        np.sum(y_true_binary[i] & y_pred_binary[i]) / np.sum(y_pred_binary[i])
        if np.sum(y_pred_binary[i]) > 0 else 0
        for i in range(y_pred_binary.shape[0])
    ])
    return DDP

# %%
def calculate_F1(DDR, DDP):
    # Check for a case where both DDR and DDP are zero to avoid division by zero
    if DDR == 0 and DDP == 0:
        return 0

    F1 = 2 * (DDR * DDP) / (DDR + DDP)
    return F1

# %%
#On validation set
y_validate_np = y_validate.values
y_test_np = y_test.values

DDR_validate = calculate_DDR(y_validate_np, y_pred_validate)
DDP_validate = calculate_DDP(y_validate_np, y_pred_validate)
F1_validate = calculate_F1(DDR_validate, DDP_validate)
print("DDR on Validation Set:", DDR_validate)
print("DDP on Validation Set:", DDP_validate)
print("F1 on Validation Set:", F1_validate)
# Out:
# DDR on Validation Set: 0.9965352038700647
# DDP on Validation Set: 0.906254342272449
# F1 on Validation Set: 0.9492530138873967

# %%
# On test set
DDR_test = calculate_DDR(y_test_np, y_pred_test)
DDP_test = calculate_DDP(y_test_np, y_pred_test)
F1_test = calculate_F1(DDR_test, DDP_test)
print("DDR on Test Set:", DDR_test)
print("DDP on Test Set:", DDP_test)
print("F1 on Test Set:", F1_test)
# Out:
# DDR on Test Set: 0.9965999921550472
# DDP on Test Set: 0.9046718765537546
# F1 on Test Set: 0.9484135329774365
